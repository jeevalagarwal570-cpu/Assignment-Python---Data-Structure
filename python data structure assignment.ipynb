# %% [markdown]
# # Data Types and Structures Questions
# ## 1. What are data structures, and why are they important?
# Data structures are specialized formats for organizing, storing, and accessing collections of data. They provide efficient ways to manage information based on its characteristics and intended use.
# They are important because:
# -Choosing the right data structure significantly impacts the efficiency and performance of your program.
# -Well-chosen data structures can:
# -Simplify data manipulation (adding, removing, modifying elements)
# -Optimize searching and sorting operations
# -Conserve memory usage
#
# ## 2. Explain the difference between mutable and immutable data types with examples.
# Mutable datatypes are the onces in which values can be modified after creation whereas in an immutable data type values can't be modified. For example: list, set (mutable) and tuple, string (immutable)
#
# ## 3. What are the main differences between lists and tuples in Python?
# The major difference between lists and tuple is that, lists are mutable data type whereas tuples are immuatble data type.
#
# ## 4. Describe how dictionaries store data.
# Dictionaries store data as key–value pairs. Each key is unique and is used to access its corresponding value.
#
# ## 5. Why might you use a set instead of a list in Python
# A set is used instead of a list when you need unique elements only and faster operations like membership checking. Sets automatically remove duplicates and are generally faster for searching.
#
# ## 6. What is a string in Python, and how is it different from a list
# A string is a sequence of characters enclosed in quotes. Unlike lists, strings are immutable, meaning they cannot be changed after creation, whereas lists are mutable and can store different data types.
#
# ## 7. How do tuples ensure data integrity in Python
# Tuples are immutable, so their values cannot be changed after creation. This ensures that the data remains constant and prevents accidental modification.
#
# ## 8. What is a hash table, and how does it relate to dictionaries in Python
# A hash table is a data structure that maps keys to values using a hash function. Dictionaries in Python use hash tables to store data, enabling fast access and retrieval.
#
# ## 9. Can lists contain different data types in Python
# Yes, lists can contain different data types such as integers, strings, floats, and even other lists within the same list.
#
# ## 10. Explain why strings are immutable in Python
# Strings are immutable to ensure memory efficiency and security. Once created, they cannot be changed, which allows Python to reuse memory and avoid accidental data modification.
#
# ## 11. What advantages do dictionaries offer over lists for certain tasks
# Dictionaries allow fast data retrieval using keys, making them efficient for searching and mapping relationships, unlike lists which require sequential searching.
#
# ## 12. How do sets handle duplicate values in Python
# Sets automatically remove duplicate values. If duplicates are added, only one copy is stored.
#
# ## 13. Describe a scenario where using a tuple would be preferable over a list
# Tuples are preferable when data should remain constant, such as storing coordinates (x, y) or fixed configurations that should not be modified.
#
# ## 14. How does the “in” keyword work differently for lists and dictionaries
# In lists, the in keyword checks for values, while in dictionaries, it checks for keys by default.
#
# ## 15. Can you modify the elements of a tuple? Explain why or why not
# No, tuple elements cannot be modified because tuples are immutable. This restriction ensures data consistency and integrity.
#
# ## 16. What is a nested dictionary, and give an example of its use case
# A nested dictionary is a dictionary inside another dictionary. It is useful for representing structured data like student records, employmee details etc.
#
# ## 17. Describe the time complexity of accessing elements in a dictionary
# Accessing elements in a dictionary has a time complexity of O(1) due to hashing, making it very fast.
#
# ## 18. In what situations are lists preferred over dictionaries
# Lists are preferred when you need an ordered collection and when accessing elements by position (index) is required.
#
# ## 19. Why are dictionaries considered unordered, and how does that affect data retrieval
# Dictionaries are considered unordered because they do not store elements based on position but on keys. Data is retrieved using keys, not index positions.
#
# ## 20. Explain the difference between a list and a dictionary in terms of data retrieval
# Lists retrieve data using index positions, while dictionaries retrieve data using keys, making dictionaries faster for searching specific elements.

# %%
# write a code to create a string with you name and print it.
name = "Jeeval"
print(name)
# Out:
# Jeeval

# %%
#Write a code to find the length of the string "Hello World"
a = "Hello World"
len(a)
# Out:
# 11

# %%
#Write a code to slice the first 3 characters from the string "Python Programming"
a = "Python Programming"
print(a[:3])
# Out:
# Pyt

# %%
#Write a code to convert the string "hello" to uppercase
a = "hello"
a.upper()
# Out:
# 'HELLO'

# %%
#Write a code to replace the word "apple" with "orange" in the string "I like apple"
a = "I like apple"
a.replace("apple" , "orange")
# Out:
# 'I like orange'

# %%
#Write a code to create a list with numbers 1 to 5 and print it
numbers = [1, 2, 3, 4, 5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Write a code to append the number 10 to the list [1, 2, 3, 4]
list_1 = [1,2,3,4]
list_1.append(10)
print(list_1)
# Out:
# [1, 2, 3, 4, 10]

# %%
#Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
a = [1,2,3,4,5]
a.remove(3)
print(a)
# Out:
# [1, 2, 4, 5]

# %%
#Write a code to access the second element in the list ['a', 'b', 'c', 'd']
list_2 = ['a' , 'b', 'c' , 'd']
print(list_2[1])
# Out:
# b

# %%
#Write a code to reverse the list [10, 20, 30, 40, 50].
nums = [10, 20, 30, 40, 50]
print(nums[::-1])
# Out:
# [50, 40, 30, 20, 10]

# %%
#Write a code to create a tuple with the elements 100, 200, 300 and print it.
t = (100, 200, 300)
print(t)

# %%
# Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').
colors = ('red', 'green', 'blue', 'yellow')
print(colors[-2])

# %%
# Write a code to find the minimum number in the tuple (10, 20, 5, 15).
a = (10, 20, 5, 15)
print(min(a))
# Out:
# 5

# %%
#Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
t = ('dog' , 'cat' , 'rabbit')
t.index('cat')
# Out:
# 1

# %%
#Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.
fruits = ("apple", "banana", "mango","kiwi")
print("kiwi" in fruits)
# Out:
# True

# %%
# Write a code to create a set with the elements 'a', 'b', 'c' and print it
set_1 = {'a' , 'b' , 'c'}
print(set_1)
# Out:
# {'b', 'c', 'a'}

# %%
#Write a code to clear all elements from the set {1, 2, 3, 4, 5}.
a = {1,2,3,4,5}
a.clear()
print(a)
# Out:
# set()

# %%
#Write a code to remove the element 4 from the set {1, 2, 3, 4}.
s = {1,2,3,4}
s.remove(4)
print(s)
# Out:
# {1, 2, 3}

# %%
# Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.
s1 = {1,2,3}
s2 = {3,4,5}
print(s1| s2)
# Out:
# {1, 2, 3, 4, 5}

# %%
#Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.
s1 = {1,2,3}
s2 = {2,3,4}
print(s1&s2)
# Out:
# {2, 3}

# %%
#Write a code to create a dictionary with the keys "name", "age", and "city", and print it.
d = {"name": "John", "age": 25, "city": "New York"}
print(d)
# Out:
# {'name': 'John', 'age': 25, 'city': 'New York'}

# %%
#write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.
d = {'name': 'John', 'age': 25}
d["country"] = "USA"
print(d)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
#Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.
d = {'name': 'Alice', 'age': 30}
print(d["name"])
# Out:
# Alice

# %%
#Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.
d = {'name': 'Bob', 'age': 22, 'city': 'New York'}
d.pop("age")
print(d)

# %%
# Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}
d = {'name': 'Alice', 'city': 'Paris'}
print("city" in d)

# %%
#Write a code to create a list, a tuple, and a dictionary, and print them all.
l = [1, 2, 3]
t = (4, 5, 6)
d = {"a": 1, "b": 2}

print(l, t, d)
# Out:
# [1, 2, 3] (4, 5, 6) {'a': 1, 'b': 2}

# %%
#Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.(replaced)
number = [45, 12, 78, 23, 9]
number.sort()
print(number)
# Out:
# [9, 12, 23, 45, 78]

# %%
#Write a code to create a list with strings and print the element at the third index.
l = ["apple", "banana", "cherry", "mango", "grape"]
print(l[3])
# Out:
# mango

# %%
#Write a code to combine two dictionaries into one and print the result.
d1 = {"a": 1, "b": 2}
d2 = {"c": 3, "d": 4}
d1.update(d2)
print(d1)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
#Write a code to convert a list of strings into a set
l = ["apple", "banana", "apple", "mango"]
s = set(l)
print(s)
# Out:
# {'apple', 'mango', 'banana'}
